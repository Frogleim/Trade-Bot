# %%
import time
import requests
from PIL import Image
from io import BytesIO
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

# %%
url = f"https://in.pinterest.com/"

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
driver.get(url)

# %%
query = 'falling wedge pattern'
search_bar = driver.find_element(By.XPATH, '//*[@id="searchBoxContainer"]/div/div/div[2]/input')
search_bar.click()
search_bar.send_keys(query)

# %%
search_bar.send_keys(Keys.ENTER)

# %%
for i in range(1,30):
    xpath = f'//*[@id="mweb-unauth-container"]/div/div[3]/div/div/div/div/div/div[{i}]/div[1]/div/div/div/div[1]/a/div/div/div/div/div[1]/img'
    print(xpath)
    try:
        image_url = driver.find_element(By.XPATH, f'//*[@id="mweb-unauth-container"]/div/div[3]/div/div/div/div/div/div[{i}]/div[1]/div/div/div/div[1]/a/div/div/div/div/div[1]/img')
        print(image_url.get_attribute('src'))
        time.sleep(0.5)
    except Exception as e:
        print(e)
# Out:
# //*[@id="mweb-unauth-container"]/div/div[3]/div/div/div/div/div/div[1]/div[1]/div/div/div/div[1]/a/div/div/div/div/div[1]/img
# https://i.pinimg.com/236x/84/e0/8c/84e08cb88386100e60e780e28b601ae3.jpg
# //*[@id="mweb-unauth-container"]/div/div[3]/div/div/div/div/div/div[2]/div[1]/div/div/div/div[1]/a/div/div/div/div/div[1]/img
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="mweb-unauth-container"]/div/div[3]/div/div/div/div/div/div[2]/div[1]/div/div/div/div[1]/a/div/div/div/div/div[1]/img"}
#   (Session info: chrome=124.0.6367.201); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# #0 0x5d9810f8ce43 <unknown>
# #1 0x5d9810c7b4e7 <unknown>
# #2 0x5d9810cc635d <unknown>
# #3 0x5d9810cc6411 <unknown>
# #4 0x5d9810d09774 <unknown>
# #5 0x5d9810ce847d <unknown>
# #6 0x5d9810d06c29 <unknown>
# #7 0x5d9810ce81f3 <unknown>
# ...
