# %%
from binance.client import Client

# %%
api_key = 'iyJXPaZztWrimkH6V57RGvStFgYQWRaaMdaYBQHHIEv0mMY1huCmrzTbXkaBjLFh'

api_secret = 'hmrus7zI9PW2EXqsDVovoS2cEFRVsxeETGgBf4XJInOLFcmIXKNL23alGRNRbXKI'
client = Client(api_key, api_secret)

# %%
client.futures_account_trades()
# Out:
# [{'symbol': 'ETHUSDT',
#   'id': 3410409575,
#   'orderId': 8389765632346407796,
#   'side': 'SELL',
#   'price': '2269.91',
#   'qty': '0.210',
#   'realizedPnl': '0.82740000',
#   'marginAsset': 'USDT',
#   'quoteQty': '476.68110',
#   'commission': '0.23834055',
#   'commissionAsset': 'USDT',
#   'time': 1701797282042,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412337981,
#   'orderId': 8389765632764434097,
#   'side': 'SELL',
#   'price': '2267.68',
#   'qty': '0.338',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '766.47584',
#   'commission': '0.15329516',
#   'commissionAsset': 'USDT',
#   'time': 1701843301513,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3412340692,
#   'orderId': 8389765632764942985,
#   'side': 'BUY',
#   'price': '2265.14',
#   'qty': '0.338',
#   'realizedPnl': '0.85851999',
#   'marginAsset': 'USDT',
#   'quoteQty': '765.61732',
#   'commission': '0.38280866',
#   'commissionAsset': 'USDT',
#   'time': 1701843418739,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412343351,
#   'orderId': 8389765632765436188,
#   'side': 'BUY',
#   'price': '2267.88',
#   'qty': '0.507',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1149.81516',
#   'commission': '0.57490758',
#   'commissionAsset': 'USDT',
#   'time': 1701843551438,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412359915,
#   'orderId': 8389765632768312565,
#   'side': 'SELL',
#   'price': '2270.79',
#   'qty': '0.507',
#   'realizedPnl': '1.47537000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1151.29053',
#   'commission': '0.57564526',
#   'commissionAsset': 'USDT',
#   'time': 1701844362017,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412398463,
#   'orderId': 8389765632773750560,
#   'side': 'BUY',
#   'price': '2274.04',
#   'qty': '0.530',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1205.24120',
#   'commission': '0.24104824',
#   'commissionAsset': 'USDT',
#   'time': 1701846358114,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3412506638,
#   'orderId': 8389765632790291060,
#   'side': 'SELL',
#   'price': '2276.55',
#   'qty': '0.530',
#   'realizedPnl': '1.33030000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1206.57150',
#   'commission': '0.60328574',
#   'commissionAsset': 'USDT',
#   'time': 1701851733181,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412539273,
#   'orderId': 8389765632794267835,
#   'side': 'BUY',
#   'price': '2280.53',
#   'qty': '0.560',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1277.09680',
#   'commission': '0.25541936',
#   'commissionAsset': 'USDT',
#   'time': 1701853065563,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3412552599,
#   'orderId': 8389765632795822759,
#   'side': 'SELL',
#   'price': '2283.28',
#   'qty': '0.560',
#   'realizedPnl': '1.54000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1278.63680',
#   'commission': '0.63931839',
#   'commissionAsset': 'USDT',
#   'time': 1701853511764,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412573802,
#   'orderId': 8389765632798006039,
#   'side': 'BUY',
#   'price': '2277.57',
#   'qty': '0.590',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1343.76630',
#   'commission': '0.26875326',
#   'commissionAsset': 'USDT',
#   'time': 1701854452004,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3412580665,
#   'orderId': 8389765632800135641,
#   'side': 'SELL',
#   'price': '2280.08',
#   'qty': '0.590',
#   'realizedPnl': '1.48090000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1345.24720',
#   'commission': '0.67262360',
#   'commissionAsset': 'USDT',
#   'time': 1701854826541,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412836104,
#   'orderId': 8389765632825641914,
#   'side': 'BUY',
#   'price': '2257',
#   'qty': '0.575',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1297.77500',
#   'commission': '0.64888749',
#   'commissionAsset': 'USDT',
#   'time': 1701861833797,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412836105,
#   'orderId': 8389765632825641914,
#   'side': 'BUY',
#   'price': '2257',
#   'qty': '0.105',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '236.98500',
#   'commission': '0.11849250',
#   'commissionAsset': 'USDT',
#   'time': 1701861833797,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412840618,
#   'orderId': 8389765632825916685,
#   'side': 'BUY',
#   'price': '2252.48',
#   'qty': '0.659',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1484.38432',
#   'commission': '0.74219216',
#   'commissionAsset': 'USDT',
#   'time': 1701861891414,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412840619,
#   'orderId': 8389765632825916685,
#   'side': 'BUY',
#   'price': '2252.48',
#   'qty': '0.051',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '114.87648',
#   'commission': '0.05743824',
#   'commissionAsset': 'USDT',
#   'time': 1701861891414,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412844758,
#   'orderId': 8389765632826216936,
#   'side': 'SELL',
#   'price': '2255.62',
#   'qty': '0.249',
#   'realizedPnl': '0.23126546',
#   'marginAsset': 'USDT',
#   'quoteQty': '561.64938',
#   'commission': '0.28082469',
#   'commissionAsset': 'USDT',
#   'time': 1701861953394,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412844759,
#   'orderId': 8389765632826216936,
#   'side': 'SELL',
#   'price': '2255.62',
#   'qty': '0.011',
#   'realizedPnl': '0.01021654',
#   'marginAsset': 'USDT',
#   'quoteQty': '24.81182',
#   'commission': '0.01240591',
#   'commissionAsset': 'USDT',
#   'time': 1701861953394,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412844760,
#   'orderId': 8389765632826216936,
#   'side': 'SELL',
#   'price': '2255.62',
#   'qty': '1.130',
#   'realizedPnl': '1.04951798',
#   'marginAsset': 'USDT',
#   'quoteQty': '2548.85060',
#   'commission': '1.27442530',
#   'commissionAsset': 'USDT',
#   'time': 1701861953394,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412850805,
#   'orderId': 8389765632826949854,
#   'side': 'SELL',
#   'price': '2256.98',
#   'qty': '0.750',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1692.73500',
#   'commission': '0.84636750',
#   'commissionAsset': 'USDT',
#   'time': 1701862104608,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412859177,
#   'orderId': 8389765632827889164,
#   'side': 'BUY',
#   'price': '2254.77',
#   'qty': '0.100',
#   'realizedPnl': '0.22100000',
#   'marginAsset': 'USDT',
#   'quoteQty': '225.47700',
#   'commission': '0.11273850',
#   'commissionAsset': 'USDT',
#   'time': 1701862295382,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412859178,
#   'orderId': 8389765632827889164,
#   'side': 'BUY',
#   'price': '2254.77',
#   'qty': '0.017',
#   'realizedPnl': '0.03757000',
#   'marginAsset': 'USDT',
#   'quoteQty': '38.33109',
#   'commission': '0.01916554',
#   'commissionAsset': 'USDT',
#   'time': 1701862295382,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412859179,
#   'orderId': 8389765632827889164,
#   'side': 'BUY',
#   'price': '2254.77',
#   'qty': '0.010',
#   'realizedPnl': '0.02210000',
#   'marginAsset': 'USDT',
#   'quoteQty': '22.54770',
#   'commission': '0.01127385',
#   'commissionAsset': 'USDT',
#   'time': 1701862295382,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412859180,
#   'orderId': 8389765632827889164,
#   'side': 'BUY',
#   'price': '2254.77',
#   'qty': '0.036',
#   'realizedPnl': '0.07956000',
#   'marginAsset': 'USDT',
#   'quoteQty': '81.17172',
#   'commission': '0.04058586',
#   'commissionAsset': 'USDT',
#   'time': 1701862295382,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412859181,
#   'orderId': 8389765632827889164,
#   'side': 'BUY',
#   'price': '2254.77',
#   'qty': '0.587',
#   'realizedPnl': '1.29727000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1323.54999',
#   'commission': '0.66177499',
#   'commissionAsset': 'USDT',
#   'time': 1701862295382,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412894686,
#   'orderId': 8389765632828924414,
#   'side': 'BUY',
#   'price': '2242.69',
#   'qty': '0.787',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1764.99703',
#   'commission': '0.35299940',
#   'commissionAsset': 'USDT',
#   'time': 1701862464856,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3412917506,
#   'orderId': 8389765632829588374,
#   'side': 'SELL',
#   'price': '2244.47',
#   'qty': '0.020',
#   'realizedPnl': '0.03560000',
#   'marginAsset': 'USDT',
#   'quoteQty': '44.88940',
#   'commission': '0.02244470',
#   'commissionAsset': 'USDT',
#   'time': 1701862583890,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412917507,
#   'orderId': 8389765632829588374,
#   'side': 'SELL',
#   'price': '2244.47',
#   'qty': '0.767',
#   'realizedPnl': '1.36526000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1721.50849',
#   'commission': '0.86075424',
#   'commissionAsset': 'USDT',
#   'time': 1701862583890,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412932905,
#   'orderId': 8389765632830825189,
#   'side': 'BUY',
#   'price': '2246.30',
#   'qty': '0.661',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1484.80430',
#   'commission': '0.74240215',
#   'commissionAsset': 'USDT',
#   'time': 1701862833051,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412932906,
#   'orderId': 8389765632830825189,
#   'side': 'BUY',
#   'price': '2246.30',
#   'qty': '0.165',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '370.63950',
#   'commission': '0.18531975',
#   'commissionAsset': 'USDT',
#   'time': 1701862833051,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412963527,
#   'orderId': 8389765632833917658,
#   'side': 'SELL',
#   'price': '2250.10',
#   'qty': '0.325',
#   'realizedPnl': '1.23500000',
#   'marginAsset': 'USDT',
#   'quoteQty': '731.28250',
#   'commission': '0.36564125',
#   'commissionAsset': 'USDT',
#   'time': 1701863513864,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412963528,
#   'orderId': 8389765632833917658,
#   'side': 'SELL',
#   'price': '2250.10',
#   'qty': '0.011',
#   'realizedPnl': '0.04180000',
#   'marginAsset': 'USDT',
#   'quoteQty': '24.75110',
#   'commission': '0.01237555',
#   'commissionAsset': 'USDT',
#   'time': 1701863513864,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412963529,
#   'orderId': 8389765632833917658,
#   'side': 'SELL',
#   'price': '2250.10',
#   'qty': '0.011',
#   'realizedPnl': '0.04180000',
#   'marginAsset': 'USDT',
#   'quoteQty': '24.75110',
#   'commission': '0.01237555',
#   'commissionAsset': 'USDT',
#   'time': 1701863513864,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412963530,
#   'orderId': 8389765632833917658,
#   'side': 'SELL',
#   'price': '2250.10',
#   'qty': '0.479',
#   'realizedPnl': '1.82020000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1077.79790',
#   'commission': '0.53889895',
#   'commissionAsset': 'USDT',
#   'time': 1701863513864,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412967930,
#   'orderId': 8389765632834485505,
#   'side': 'BUY',
#   'price': '2251.41',
#   'qty': '0.185',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '416.51085',
#   'commission': '0.08330216',
#   'commissionAsset': 'USDT',
#   'time': 1701863679582,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3412967931,
#   'orderId': 8389765632834485505,
#   'side': 'BUY',
#   'price': '2251.41',
#   'qty': '0.015',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '33.77115',
#   'commission': '0.00675423',
#   'commissionAsset': 'USDT',
#   'time': 1701863679585,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3412975872,
#   'orderId': 8389765632835253670,
#   'side': 'SELL',
#   'price': '2253.68',
#   'qty': '0.200',
#   'realizedPnl': '0.45400000',
#   'marginAsset': 'USDT',
#   'quoteQty': '450.73600',
#   'commission': '0.22536800',
#   'commissionAsset': 'USDT',
#   'time': 1701863881234,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412991977,
#   'orderId': 8389765632836716247,
#   'side': 'BUY',
#   'price': '2256.82',
#   'qty': '0.009',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '20.31138',
#   'commission': '0.01015569',
#   'commissionAsset': 'USDT',
#   'time': 1701864303075,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412993080,
#   'orderId': 8389765632836827741,
#   'side': 'SELL',
#   'price': '2257.73',
#   'qty': '0.009',
#   'realizedPnl': '0.00818999',
#   'marginAsset': 'USDT',
#   'quoteQty': '20.31957',
#   'commission': '0.01015978',
#   'commissionAsset': 'USDT',
#   'time': 1701864339662,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412995534,
#   'orderId': 8389765632837027841,
#   'side': 'BUY',
#   'price': '2259.41',
#   'qty': '0.009',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '20.33469',
#   'commission': '0.01016734',
#   'commissionAsset': 'USDT',
#   'time': 1701864406586,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3412995682,
#   'orderId': 8389765632837045506,
#   'side': 'SELL',
#   'price': '2259.54',
#   'qty': '0.009',
#   'realizedPnl': '0.00117000',
#   'marginAsset': 'USDT',
#   'quoteQty': '20.33586',
#   'commission': '0.01016793',
#   'commissionAsset': 'USDT',
#   'time': 1701864409505,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413008815,
#   'orderId': 8389765632838200403,
#   'side': 'BUY',
#   'price': '2259.84',
#   'qty': '0.300',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '677.95200',
#   'commission': '0.33897600',
#   'commissionAsset': 'USDT',
#   'time': 1701864686685,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413054910,
#   'orderId': 8389765632844676075,
#   'side': 'SELL',
#   'price': '2263.07',
#   'qty': '0.300',
#   'realizedPnl': '0.96900000',
#   'marginAsset': 'USDT',
#   'quoteQty': '678.92100',
#   'commission': '0.33946050',
#   'commissionAsset': 'USDT',
#   'time': 1701866433044,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413060643,
#   'orderId': 8389765632845358690,
#   'side': 'BUY',
#   'price': '2264.84',
#   'qty': '0.088',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '199.30592',
#   'commission': '0.03986118',
#   'commissionAsset': 'USDT',
#   'time': 1701866619880,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3413060646,
#   'orderId': 8389765632845358690,
#   'side': 'BUY',
#   'price': '2264.84',
#   'qty': '0.170',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '385.02280',
#   'commission': '0.07700456',
#   'commissionAsset': 'USDT',
#   'time': 1701866620376,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3413060653,
#   'orderId': 8389765632845358690,
#   'side': 'BUY',
#   'price': '2264.84',
#   'qty': '0.057',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '129.09588',
#   'commission': '0.02581917',
#   'commissionAsset': 'USDT',
#   'time': 1701866620733,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3413067392,
#   'orderId': 8389765632846006120,
#   'side': 'SELL',
#   'price': '2266.54',
#   'qty': '0.315',
#   'realizedPnl': '0.53550000',
#   'marginAsset': 'USDT',
#   'quoteQty': '713.96010',
#   'commission': '0.35698005',
#   'commissionAsset': 'USDT',
#   'time': 1701866784418,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413074140,
#   'orderId': 8389765632846711390,
#   'side': 'BUY',
#   'price': '2267.12',
#   'qty': '0.011',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '24.93832',
#   'commission': '0.01246916',
#   'commissionAsset': 'USDT',
#   'time': 1701866951386,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413074141,
#   'orderId': 8389765632846711390,
#   'side': 'BUY',
#   'price': '2267.12',
#   'qty': '0.320',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '725.47840',
#   'commission': '0.36273920',
#   'commissionAsset': 'USDT',
#   'time': 1701866951386,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413491086,
#   'orderId': 8389765632900008273,
#   'side': 'SELL',
#   'price': '2271.29',
#   'qty': '0.331',
#   'realizedPnl': '1.38027000',
#   'marginAsset': 'USDT',
#   'quoteQty': '751.79699',
#   'commission': '0.37589849',
#   'commissionAsset': 'USDT',
#   'time': 1701881106547,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413496924,
#   'orderId': 8389765632900673065,
#   'side': 'BUY',
#   'price': '2267.79',
#   'qty': '0.348',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '789.19092',
#   'commission': '0.39459546',
#   'commissionAsset': 'USDT',
#   'time': 1701881252844,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413519078,
#   'orderId': 8389765632903922102,
#   'side': 'SELL',
#   'price': '2272',
#   'qty': '0.348',
#   'realizedPnl': '1.46508000',
#   'marginAsset': 'USDT',
#   'quoteQty': '790.65600',
#   'commission': '0.39532800',
#   'commissionAsset': 'USDT',
#   'time': 1701882100598,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413529409,
#   'orderId': 8389765632904828516,
#   'side': 'BUY',
#   'price': '2274.17',
#   'qty': '0.365',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '830.07205',
#   'commission': '0.16601441',
#   'commissionAsset': 'USDT',
#   'time': 1701882336881,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3413531765,
#   'orderId': 8389765632904954563,
#   'side': 'SELL',
#   'price': '2275.97',
#   'qty': '0.365',
#   'realizedPnl': '0.65700000',
#   'marginAsset': 'USDT',
#   'quoteQty': '830.72905',
#   'commission': '0.41536452',
#   'commissionAsset': 'USDT',
#   'time': 1701882352043,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413549475,
#   'orderId': 8389765632906199852,
#   'side': 'SELL',
#   'price': '2281',
#   'qty': '0.015',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '34.21500',
#   'commission': '0.01710750',
#   'commissionAsset': 'USDT',
#   'time': 1701882648021,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413549476,
#   'orderId': 8389765632906199852,
#   'side': 'SELL',
#   'price': '2281',
#   'qty': '0.368',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '839.40800',
#   'commission': '0.41970400',
#   'commissionAsset': 'USDT',
#   'time': 1701882648021,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413578484,
#   'orderId': 8389765632909055230,
#   'side': 'BUY',
#   'price': '2277.39',
#   'qty': '0.383',
#   'realizedPnl': '1.38263000',
#   'marginAsset': 'USDT',
#   'quoteQty': '872.24037',
#   'commission': '0.43612018',
#   'commissionAsset': 'USDT',
#   'time': 1701883370463,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3413672050,
#   'orderId': 8389765632924145577,
#   'side': 'BUY',
#   'price': '2273.71',
#   'qty': '0.338',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '768.51398',
#   'commission': '0.38425699',
#   'commissionAsset': 'USDT',
#   'time': 1701887756543,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415404133,
#   'orderId': 8389765633129655727,
#   'side': 'SELL',
#   'price': '2277.67',
#   'qty': '0.338',
#   'realizedPnl': '1.33848000',
#   'marginAsset': 'USDT',
#   'quoteQty': '769.85246',
#   'commission': '0.38492623',
#   'commissionAsset': 'USDT',
#   'time': 1701961412003,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415423271,
#   'orderId': 8389765633130642863,
#   'side': 'BUY',
#   'price': '2274.17',
#   'qty': '0.507',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1153.00419',
#   'commission': '0.57650209',
#   'commissionAsset': 'USDT',
#   'time': 1701961580059,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415431712,
#   'orderId': 8389765633131171732,
#   'side': 'SELL',
#   'price': '2276.70',
#   'qty': '0.507',
#   'realizedPnl': '1.28271000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1154.28690',
#   'commission': '0.57714345',
#   'commissionAsset': 'USDT',
#   'time': 1701961733645,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415568128,
#   'orderId': 8389765633136957936,
#   'side': 'SELL',
#   'price': '2306.49',
#   'qty': '0.760',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1752.93240',
#   'commission': '0.87646620',
#   'commissionAsset': 'USDT',
#   'time': 1701962776620,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415795123,
#   'orderId': 8389765633147012209,
#   'side': 'BUY',
#   'price': '2326.17',
#   'qty': '0.760',
#   'realizedPnl': '-14.95680000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1767.88920',
#   'commission': '0.88394460',
#   'commissionAsset': 'USDT',
#   'time': 1701964365279,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415795146,
#   'orderId': 8389765633147015449,
#   'side': 'BUY',
#   'price': '2326.45',
#   'qty': '0.011',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '25.59095',
#   'commission': '0.01279547',
#   'commissionAsset': 'USDT',
#   'time': 1701964365659,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415795147,
#   'orderId': 8389765633147015449,
#   'side': 'BUY',
#   'price': '2326.45',
#   'qty': '0.011',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '25.59095',
#   'commission': '0.01279547',
#   'commissionAsset': 'USDT',
#   'time': 1701964365659,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415795148,
#   'orderId': 8389765633147015449,
#   'side': 'BUY',
#   'price': '2326.46',
#   'qty': '0.038',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '88.40548',
#   'commission': '0.04420274',
#   'commissionAsset': 'USDT',
#   'time': 1701964365659,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415795149,
#   'orderId': 8389765633147015449,
#   'side': 'BUY',
#   'price': '2326.56',
#   'qty': '0.020',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '46.53120',
#   'commission': '0.02326560',
#   'commissionAsset': 'USDT',
#   'time': 1701964365659,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415795150,
#   'orderId': 8389765633147015449,
#   'side': 'BUY',
#   'price': '2326.56',
#   'qty': '0.009',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '20.93904',
#   'commission': '0.01046952',
#   'commissionAsset': 'USDT',
#   'time': 1701964365659,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415795151,
#   'orderId': 8389765633147015449,
#   'side': 'BUY',
#   'price': '2326.67',
#   'qty': '0.060',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '139.60020',
#   'commission': '0.06980010',
#   'commissionAsset': 'USDT',
#   'time': 1701964365659,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415795152,
#   'orderId': 8389765633147015449,
#   'side': 'BUY',
#   'price': '2326.68',
#   'qty': '0.611',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1421.60148',
#   'commission': '0.71080074',
#   'commissionAsset': 'USDT',
#   'time': 1701964365659,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415839744,
#   'orderId': 8389765633149626943,
#   'side': 'SELL',
#   'price': '2325.25',
#   'qty': '0.760',
#   'realizedPnl': '-1.06929999',
#   'marginAsset': 'USDT',
#   'quoteQty': '1767.19000',
#   'commission': '0.88359500',
#   'commissionAsset': 'USDT',
#   'time': 1701964841993,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415845188,
#   'orderId': 8389765633149991024,
#   'side': 'SELL',
#   'price': '2322.86',
#   'qty': '1.140',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '2648.06040',
#   'commission': '0.52961208',
#   'commissionAsset': 'USDT',
#   'time': 1701964909004,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3415847239,
#   'orderId': 8389765633150074151,
#   'side': 'BUY',
#   'price': '2319.71',
#   'qty': '1.140',
#   'realizedPnl': '3.59100000',
#   'marginAsset': 'USDT',
#   'quoteQty': '2644.46940',
#   'commission': '1.32223470',
#   'commissionAsset': 'USDT',
#   'time': 1701964924924,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415886621,
#   'orderId': 8389765633151907089,
#   'side': 'BUY',
#   'price': '2330.27',
#   'qty': '0.372',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '866.86044',
#   'commission': '0.17337208',
#   'commissionAsset': 'USDT',
#   'time': 1701965222712,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3415886623,
#   'orderId': 8389765633151907089,
#   'side': 'BUY',
#   'price': '2330.27',
#   'qty': '0.328',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '764.32856',
#   'commission': '0.15286571',
#   'commissionAsset': 'USDT',
#   'time': 1701965222732,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3415890519,
#   'orderId': 8389765633152224890,
#   'side': 'SELL',
#   'price': '2332.26',
#   'qty': '0.700',
#   'realizedPnl': '1.39300000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1632.58200',
#   'commission': '0.81629100',
#   'commissionAsset': 'USDT',
#   'time': 1701965248286,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415909591,
#   'orderId': 8389765633152930923,
#   'side': 'BUY',
#   'price': '2334.92',
#   'qty': '0.700',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1634.44400',
#   'commission': '0.32688879',
#   'commissionAsset': 'USDT',
#   'time': 1701965371806,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3415918833,
#   'orderId': 8389765633153440027,
#   'side': 'SELL',
#   'price': '2336.02',
#   'qty': '0.700',
#   'realizedPnl': '0.77000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1635.21400',
#   'commission': '0.81760700',
#   'commissionAsset': 'USDT',
#   'time': 1701965445611,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415934578,
#   'orderId': 8389765633153953141,
#   'side': 'BUY',
#   'price': '2340.44',
#   'qty': '0.143',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '334.68292',
#   'commission': '0.16734146',
#   'commissionAsset': 'USDT',
#   'time': 1701965530138,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415934579,
#   'orderId': 8389765633153953141,
#   'side': 'BUY',
#   'price': '2340.44',
#   'qty': '0.592',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1385.54048',
#   'commission': '0.69277024',
#   'commissionAsset': 'USDT',
#   'time': 1701965530138,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3415971010,
#   'orderId': 8389765633155704544,
#   'side': 'SELL',
#   'price': '2344.79',
#   'qty': '0.735',
#   'realizedPnl': '3.19725000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1723.42065',
#   'commission': '0.86171032',
#   'commissionAsset': 'USDT',
#   'time': 1701965810019,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416021523,
#   'orderId': 8389765633158890027,
#   'side': 'SELL',
#   'price': '2344.49',
#   'qty': '0.011',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '25.78939',
#   'commission': '0.01289469',
#   'commissionAsset': 'USDT',
#   'time': 1701966339300,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416021524,
#   'orderId': 8389765633158890027,
#   'side': 'SELL',
#   'price': '2344.49',
#   'qty': '0.761',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '1784.15689',
#   'commission': '0.89207844',
#   'commissionAsset': 'USDT',
#   'time': 1701966339300,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416027181,
#   'orderId': 8389765633159170033,
#   'side': 'BUY',
#   'price': '2345.37',
#   'qty': '0.500',
#   'realizedPnl': '-0.44000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '1172.68500',
#   'commission': '0.58634250',
#   'commissionAsset': 'USDT',
#   'time': 1701966384626,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416027182,
#   'orderId': 8389765633159170033,
#   'side': 'BUY',
#   'price': '2345.37',
#   'qty': '0.272',
#   'realizedPnl': '-0.23936000',
#   'marginAsset': 'USDT',
#   'quoteQty': '637.94064',
#   'commission': '0.31897031',
#   'commissionAsset': 'USDT',
#   'time': 1701966384626,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416060633,
#   'orderId': 8389765633161262443,
#   'side': 'BUY',
#   'price': '2348.12',
#   'qty': '0.020',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '46.96240',
#   'commission': '0.00939248',
#   'commissionAsset': 'USDT',
#   'time': 1701966794480,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3416075007,
#   'orderId': 8389765633161716629,
#   'side': 'SELL',
#   'price': '2351.48',
#   'qty': '0.020',
#   'realizedPnl': '0.06720000',
#   'marginAsset': 'USDT',
#   'quoteQty': '47.02960',
#   'commission': '0.02351480',
#   'commissionAsset': 'USDT',
#   'time': 1701966864769,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416085521,
#   'orderId': 8389765633162329594,
#   'side': 'BUY',
#   'price': '2348.84',
#   'qty': '0.021',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '49.32564',
#   'commission': '0.02466282',
#   'commissionAsset': 'USDT',
#   'time': 1701966970350,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416103410,
#   'orderId': 8389765633163464776,
#   'side': 'SELL',
#   'price': '2353.39',
#   'qty': '0.021',
#   'realizedPnl': '0.09555000',
#   'marginAsset': 'USDT',
#   'quoteQty': '49.42119',
#   'commission': '0.02471059',
#   'commissionAsset': 'USDT',
#   'time': 1701967185283,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416132562,
#   'orderId': 8389765633166064924,
#   'side': 'SELL',
#   'price': '2350.16',
#   'qty': '0.120',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '282.01920',
#   'commission': '0.14100960',
#   'commissionAsset': 'USDT',
#   'time': 1701967690011,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416144421,
#   'orderId': 8389765633167640362,
#   'side': 'BUY',
#   'price': '2346.74',
#   'qty': '0.120',
#   'realizedPnl': '0.41039999',
#   'marginAsset': 'USDT',
#   'quoteQty': '281.60880',
#   'commission': '0.14080440',
#   'commissionAsset': 'USDT',
#   'time': 1701968016141,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416154397,
#   'orderId': 8389765633168461105,
#   'side': 'SELL',
#   'price': '2350.46',
#   'qty': '0.126',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '296.15796',
#   'commission': '0.14807898',
#   'commissionAsset': 'USDT',
#   'time': 1701968184013,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416156854,
#   'orderId': 8389765633168776039,
#   'side': 'BUY',
#   'price': '2347.33',
#   'qty': '0.126',
#   'realizedPnl': '0.39438000',
#   'marginAsset': 'USDT',
#   'quoteQty': '295.76358',
#   'commission': '0.14788179',
#   'commissionAsset': 'USDT',
#   'time': 1701968236500,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416250698,
#   'orderId': 8389765633174846700,
#   'side': 'BUY',
#   'price': '2343',
#   'qty': '0.130',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '304.59000',
#   'commission': '0.15229500',
#   'commissionAsset': 'USDT',
#   'time': 1701969410767,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416254714,
#   'orderId': 8389765633175039646,
#   'side': 'SELL',
#   'price': '2344.84',
#   'qty': '0.130',
#   'realizedPnl': '0.23920000',
#   'marginAsset': 'USDT',
#   'quoteQty': '304.82920',
#   'commission': '0.15241460',
#   'commissionAsset': 'USDT',
#   'time': 1701969443017,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416276286,
#   'orderId': 8389765633176704697,
#   'side': 'BUY',
#   'price': '2341.83',
#   'qty': '0.195',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '456.65685',
#   'commission': '0.22832842',
#   'commissionAsset': 'USDT',
#   'time': 1701969821515,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416420943,
#   'orderId': 8389765633192726892,
#   'side': 'SELL',
#   'price': '2344.84',
#   'qty': '0.195',
#   'realizedPnl': '0.58695000',
#   'marginAsset': 'USDT',
#   'quoteQty': '457.24380',
#   'commission': '0.22862190',
#   'commissionAsset': 'USDT',
#   'time': 1701973481592,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416465160,
#   'orderId': 8389765633197221935,
#   'side': 'SELL',
#   'price': '2344.37',
#   'qty': '0.290',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '679.86730',
#   'commission': '0.33993365',
#   'commissionAsset': 'USDT',
#   'time': 1701974506210,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416523859,
#   'orderId': 8389765633201729285,
#   'side': 'BUY',
#   'price': '2342.09',
#   'qty': '0.290',
#   'realizedPnl': '0.66119999',
#   'marginAsset': 'USDT',
#   'quoteQty': '679.20610',
#   'commission': '0.33960305',
#   'commissionAsset': 'USDT',
#   'time': 1701975480023,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416528335,
#   'orderId': 8389765633202084259,
#   'side': 'SELL',
#   'price': '2342.15',
#   'qty': '0.290',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '679.22350',
#   'commission': '0.33961175',
#   'commissionAsset': 'USDT',
#   'time': 1701975563877,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416531736,
#   'orderId': 8389765633202288817,
#   'side': 'BUY',
#   'price': '2339.20',
#   'qty': '0.011',
#   'realizedPnl': '0.03245000',
#   'marginAsset': 'USDT',
#   'quoteQty': '25.73120',
#   'commission': '0.01286560',
#   'commissionAsset': 'USDT',
#   'time': 1701975606728,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416531737,
#   'orderId': 8389765633202288817,
#   'side': 'BUY',
#   'price': '2339.20',
#   'qty': '0.009',
#   'realizedPnl': '0.02655000',
#   'marginAsset': 'USDT',
#   'quoteQty': '21.05280',
#   'commission': '0.01052640',
#   'commissionAsset': 'USDT',
#   'time': 1701975606728,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416531738,
#   'orderId': 8389765633202288817,
#   'side': 'BUY',
#   'price': '2339.22',
#   'qty': '0.149',
#   'realizedPnl': '0.43657000',
#   'marginAsset': 'USDT',
#   'quoteQty': '348.54378',
#   'commission': '0.17427189',
#   'commissionAsset': 'USDT',
#   'time': 1701975606728,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416531739,
#   'orderId': 8389765633202288817,
#   'side': 'BUY',
#   'price': '2339.22',
#   'qty': '0.009',
#   'realizedPnl': '0.02637000',
#   'marginAsset': 'USDT',
#   'quoteQty': '21.05298',
#   'commission': '0.01052649',
#   'commissionAsset': 'USDT',
#   'time': 1701975606728,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416531740,
#   'orderId': 8389765633202288817,
#   'side': 'BUY',
#   'price': '2339.22',
#   'qty': '0.112',
#   'realizedPnl': '0.32816000',
#   'marginAsset': 'USDT',
#   'quoteQty': '261.99264',
#   'commission': '0.13099632',
#   'commissionAsset': 'USDT',
#   'time': 1701975606728,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416544027,
#   'orderId': 8389765633203221219,
#   'side': 'SELL',
#   'price': '2338',
#   'qty': '0.290',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '678.02000',
#   'commission': '0.13560400',
#   'commissionAsset': 'USDT',
#   'time': 1701975780973,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3416571959,
#   'orderId': 8389765633207140866,
#   'side': 'BUY',
#   'price': '2334.21',
#   'qty': '0.055',
#   'realizedPnl': '0.20845000',
#   'marginAsset': 'USDT',
#   'quoteQty': '128.38155',
#   'commission': '0.06419077',
#   'commissionAsset': 'USDT',
#   'time': 1701976683994,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416571960,
#   'orderId': 8389765633207140866,
#   'side': 'BUY',
#   'price': '2334.21',
#   'qty': '0.103',
#   'realizedPnl': '0.39037000',
#   'marginAsset': 'USDT',
#   'quoteQty': '240.42363',
#   'commission': '0.12021181',
#   'commissionAsset': 'USDT',
#   'time': 1701976683994,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416571961,
#   'orderId': 8389765633207140866,
#   'side': 'BUY',
#   'price': '2334.21',
#   'qty': '0.132',
#   'realizedPnl': '0.50028000',
#   'marginAsset': 'USDT',
#   'quoteQty': '308.11572',
#   'commission': '0.15405786',
#   'commissionAsset': 'USDT',
#   'time': 1701976683994,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416578769,
#   'orderId': 8389765633207964727,
#   'side': 'BUY',
#   'price': '2332.58',
#   'qty': '0.290',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '676.44820',
#   'commission': '0.33822410',
#   'commissionAsset': 'USDT',
#   'time': 1701976878877,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416581916,
#   'orderId': 8389765633207746770,
#   'side': 'SELL',
#   'price': '2334.84',
#   'qty': '0.290',
#   'realizedPnl': '0.65540000',
#   'marginAsset': 'USDT',
#   'quoteQty': '677.10360',
#   'commission': '0.13542072',
#   'commissionAsset': 'USDT',
#   'time': 1701976975989,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3416582740,
#   'orderId': 8389765633208451450,
#   'side': 'SELL',
#   'price': '2333.52',
#   'qty': '0.007',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '16.33464',
#   'commission': '0.00816732',
#   'commissionAsset': 'USDT',
#   'time': 1701977003924,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416582741,
#   'orderId': 8389765633208451450,
#   'side': 'SELL',
#   'price': '2333.52',
#   'qty': '0.283',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '660.38616',
#   'commission': '0.33019308',
#   'commissionAsset': 'USDT',
#   'time': 1701977003924,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416591791,
#   'orderId': 8389765633209520084,
#   'side': 'BUY',
#   'price': '2331.33',
#   'qty': '0.290',
#   'realizedPnl': '0.63510000',
#   'marginAsset': 'USDT',
#   'quoteQty': '676.08570',
#   'commission': '0.33804285',
#   'commissionAsset': 'USDT',
#   'time': 1701977275754,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416611350,
#   'orderId': 8389765633211246542,
#   'side': 'SELL',
#   'price': '2334.55',
#   'qty': '0.290',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '677.01950',
#   'commission': '0.33850975',
#   'commissionAsset': 'USDT',
#   'time': 1701977668202,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416619965,
#   'orderId': 8389765633212475603,
#   'side': 'BUY',
#   'price': '2331.27',
#   'qty': '0.290',
#   'realizedPnl': '0.95120000',
#   'marginAsset': 'USDT',
#   'quoteQty': '676.06830',
#   'commission': '0.33803415',
#   'commissionAsset': 'USDT',
#   'time': 1701977995007,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416622439,
#   'orderId': 8389765633212815705,
#   'side': 'SELL',
#   'price': '2330.88',
#   'qty': '0.106',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '247.07328',
#   'commission': '0.12353664',
#   'commissionAsset': 'USDT',
#   'time': 1701978078864,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416622440,
#   'orderId': 8389765633212815705,
#   'side': 'SELL',
#   'price': '2330.88',
#   'qty': '0.014',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '32.63232',
#   'commission': '0.01631616',
#   'commissionAsset': 'USDT',
#   'time': 1701978078864,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3416622441,
#   'orderId': 8389765633212815705,
#   'side': 'SELL',
#   'price': '2330.88',
#   'qty': '0.170',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '396.24960',
#   'commission': '0.19812480',
#   'commissionAsset': 'USDT',
#   'time': 1701978078864,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417565755,
#   'orderId': 8389765633315392070,
#   'side': 'BUY',
#   'price': '2386.20',
#   'qty': '0.111',
#   'realizedPnl': '-6.14052000',
#   'marginAsset': 'USDT',
#   'quoteQty': '264.86820',
#   'commission': '0.13243410',
#   'commissionAsset': 'USDT',
#   'time': 1702009756120,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417565756,
#   'orderId': 8389765633315392070,
#   'side': 'BUY',
#   'price': '2386.20',
#   'qty': '0.012',
#   'realizedPnl': '-0.66384000',
#   'marginAsset': 'USDT',
#   'quoteQty': '28.63440',
#   'commission': '0.01431720',
#   'commissionAsset': 'USDT',
#   'time': 1702009756120,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417565757,
#   'orderId': 8389765633315392070,
#   'side': 'BUY',
#   'price': '2386.20',
#   'qty': '0.020',
#   'realizedPnl': '-1.10640000',
#   'marginAsset': 'USDT',
#   'quoteQty': '47.72400',
#   'commission': '0.02386200',
#   'commissionAsset': 'USDT',
#   'time': 1702009756120,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417565758,
#   'orderId': 8389765633315392070,
#   'side': 'BUY',
#   'price': '2386.21',
#   'qty': '0.009',
#   'realizedPnl': '-0.49797000',
#   'marginAsset': 'USDT',
#   'quoteQty': '21.47589',
#   'commission': '0.01073794',
#   'commissionAsset': 'USDT',
#   'time': 1702009756120,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417565759,
#   'orderId': 8389765633315392070,
#   'side': 'BUY',
#   'price': '2386.23',
#   'qty': '0.138',
#   'realizedPnl': '-7.63830000',
#   'marginAsset': 'USDT',
#   'quoteQty': '329.29974',
#   'commission': '0.16464987',
#   'commissionAsset': 'USDT',
#   'time': 1702009756120,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417685146,
#   'orderId': 8389765633331996795,
#   'side': 'BUY',
#   'price': '2376.41',
#   'qty': '0.020',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '47.52820',
#   'commission': '0.02376410',
#   'commissionAsset': 'USDT',
#   'time': 1702015418632,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417693435,
#   'orderId': 8389765633333490684,
#   'side': 'SELL',
#   'price': '2380.12',
#   'qty': '0.020',
#   'realizedPnl': '0.07420000',
#   'marginAsset': 'USDT',
#   'quoteQty': '47.60240',
#   'commission': '0.02380120',
#   'commissionAsset': 'USDT',
#   'time': 1702015885767,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417702663,
#   'orderId': 8389765633335023210,
#   'side': 'BUY',
#   'price': '2381.49',
#   'qty': '0.020',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '47.62980',
#   'commission': '0.02381490',
#   'commissionAsset': 'USDT',
#   'time': 1702016308746,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417711190,
#   'orderId': 8389765633336826296,
#   'side': 'SELL',
#   'price': '2377.53',
#   'qty': '0.020',
#   'realizedPnl': '-0.07919999',
#   'marginAsset': 'USDT',
#   'quoteQty': '47.55060',
#   'commission': '0.02377530',
#   'commissionAsset': 'USDT',
#   'time': 1702016938992,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417741297,
#   'orderId': 8389765633341810515,
#   'side': 'BUY',
#   'price': '2376.41',
#   'qty': '0.020',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '47.52820',
#   'commission': '0.02376410',
#   'commissionAsset': 'USDT',
#   'time': 1702018333823,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417744306,
#   'orderId': 8389765633342189264,
#   'side': 'SELL',
#   'price': '2379.38',
#   'qty': '0.020',
#   'realizedPnl': '0.05940000',
#   'marginAsset': 'USDT',
#   'quoteQty': '47.58760',
#   'commission': '0.02379380',
#   'commissionAsset': 'USDT',
#   'time': 1702018493036,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417749396,
#   'orderId': 8389765633343009185,
#   'side': 'SELL',
#   'price': '2375.39',
#   'qty': '0.030',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '71.26170',
#   'commission': '0.03563085',
#   'commissionAsset': 'USDT',
#   'time': 1702018847718,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417754084,
#   'orderId': 8389765633343853316,
#   'side': 'BUY',
#   'price': '2372.69',
#   'qty': '0.030',
#   'realizedPnl': '0.08099999',
#   'marginAsset': 'USDT',
#   'quoteQty': '71.18070',
#   'commission': '0.03559035',
#   'commissionAsset': 'USDT',
#   'time': 1702019128260,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417768030,
#   'orderId': 8389765633346183361,
#   'side': 'SELL',
#   'price': '2372',
#   'qty': '0.110',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '260.92000',
#   'commission': '0.13046000',
#   'commissionAsset': 'USDT',
#   'time': 1702019871323,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417773774,
#   'orderId': 8389765633346751825,
#   'side': 'BUY',
#   'price': '2368.99',
#   'qty': '0.110',
#   'realizedPnl': '0.33110000',
#   'marginAsset': 'USDT',
#   'quoteQty': '260.58890',
#   'commission': '0.13029445',
#   'commissionAsset': 'USDT',
#   'time': 1702020062486,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3417781700,
#   'orderId': 8389765633347185296,
#   'side': 'SELL',
#   'price': '2365.74',
#   'qty': '0.114',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '269.69436',
#   'commission': '0.13484718',
# ...
#   'marginAsset': 'USDT',
#   'quoteQty': '162.23280',
#   'commission': '0.08111640',
#   'commissionAsset': 'USDT',
#   'time': 1702213051294,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422334817,
#   'orderId': 8389765633894066221,
#   'side': 'BUY',
#   'price': '2342.59',
#   'qty': '0.084',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '196.77756',
#   'commission': '0.09838878',
#   'commissionAsset': 'USDT',
#   'time': 1702215039958,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422340279,
#   'orderId': 8389765633894927558,
#   'side': 'SELL',
#   'price': '2345.48',
#   'qty': '0.084',
#   'realizedPnl': '0.24276000',
#   'marginAsset': 'USDT',
#   'quoteQty': '197.02032',
#   'commission': '0.09851016',
#   'commissionAsset': 'USDT',
#   'time': 1702215442352,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422341338,
#   'orderId': 8389765633895183618,
#   'side': 'BUY',
#   'price': '2345.79',
#   'qty': '0.088',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '206.42952',
#   'commission': '0.10321476',
#   'commissionAsset': 'USDT',
#   'time': 1702215536691,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422343884,
#   'orderId': 8389765633895584505,
#   'side': 'SELL',
#   'price': '2347.76',
#   'qty': '0.088',
#   'realizedPnl': '0.17336000',
#   'marginAsset': 'USDT',
#   'quoteQty': '206.60288',
#   'commission': '0.10330144',
#   'commissionAsset': 'USDT',
#   'time': 1702215703013,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422376795,
#   'orderId': 8389765633900299605,
#   'side': 'BUY',
#   'price': '2349.86',
#   'qty': '0.092',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '216.18712',
#   'commission': '0.10809356',
#   'commissionAsset': 'USDT',
#   'time': 1702217617496,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422407624,
#   'orderId': 8389765633905873397,
#   'side': 'SELL',
#   'price': '2353.60',
#   'qty': '0.038',
#   'realizedPnl': '0.14212000',
#   'marginAsset': 'USDT',
#   'quoteQty': '89.43680',
#   'commission': '0.04471840',
#   'commissionAsset': 'USDT',
#   'time': 1702219742142,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422407625,
#   'orderId': 8389765633905873397,
#   'side': 'SELL',
#   'price': '2353.60',
#   'qty': '0.054',
#   'realizedPnl': '0.20196000',
#   'marginAsset': 'USDT',
#   'quoteQty': '127.09440',
#   'commission': '0.06354720',
#   'commissionAsset': 'USDT',
#   'time': 1702219742142,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422412898,
#   'orderId': 8389765633906470914,
#   'side': 'BUY',
#   'price': '2351.41',
#   'qty': '0.097',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '228.08677',
#   'commission': '0.04561735',
#   'commissionAsset': 'USDT',
#   'time': 1702219929865,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3422440511,
#   'orderId': 8389765633911085722,
#   'side': 'SELL',
#   'price': '2354.04',
#   'qty': '0.015',
#   'realizedPnl': '0.03945000',
#   'marginAsset': 'USDT',
#   'quoteQty': '35.31060',
#   'commission': '0.01765529',
#   'commissionAsset': 'USDT',
#   'time': 1702221442210,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422440512,
#   'orderId': 8389765633911085722,
#   'side': 'SELL',
#   'price': '2354.04',
#   'qty': '0.082',
#   'realizedPnl': '0.21566000',
#   'marginAsset': 'USDT',
#   'quoteQty': '193.03128',
#   'commission': '0.09651564',
#   'commissionAsset': 'USDT',
#   'time': 1702221442210,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422481436,
#   'orderId': 8389765633916969265,
#   'side': 'BUY',
#   'price': '2354.75',
#   'qty': '0.102',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '240.18450',
#   'commission': '0.12009225',
#   'commissionAsset': 'USDT',
#   'time': 1702223466339,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422494725,
#   'orderId': 8389765633919601616,
#   'side': 'SELL',
#   'price': '2356.86',
#   'qty': '0.102',
#   'realizedPnl': '0.21522000',
#   'marginAsset': 'USDT',
#   'quoteQty': '240.39972',
#   'commission': '0.12019986',
#   'commissionAsset': 'USDT',
#   'time': 1702224396595,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422496814,
#   'orderId': 8389765633919885271,
#   'side': 'BUY',
#   'price': '2357.55',
#   'qty': '0.107',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '252.25785',
#   'commission': '0.05045157',
#   'commissionAsset': 'USDT',
#   'time': 1702224505007,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3422624195,
#   'orderId': 8389765633941667233,
#   'side': 'SELL',
#   'price': '2361.15',
#   'qty': '0.107',
#   'realizedPnl': '0.38520000',
#   'marginAsset': 'USDT',
#   'quoteQty': '252.64305',
#   'commission': '0.12632152',
#   'commissionAsset': 'USDT',
#   'time': 1702233023869,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422631974,
#   'orderId': 8389765633942146321,
#   'side': 'BUY',
#   'price': '2359.71',
#   'qty': '0.083',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '195.85593',
#   'commission': '0.09792796',
#   'commissionAsset': 'USDT',
#   'time': 1702233149183,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422631975,
#   'orderId': 8389765633942146321,
#   'side': 'BUY',
#   'price': '2359.71',
#   'qty': '0.029',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '68.43159',
#   'commission': '0.03421579',
#   'commissionAsset': 'USDT',
#   'time': 1702233149183,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422722729,
#   'orderId': 8389765633956258337,
#   'side': 'SELL',
#   'price': '2362.97',
#   'qty': '0.112',
#   'realizedPnl': '0.36512000',
#   'marginAsset': 'USDT',
#   'quoteQty': '264.65264',
#   'commission': '0.13232632',
#   'commissionAsset': 'USDT',
#   'time': 1702239877208,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3422796041,
#   'orderId': 8389765633962194355,
#   'side': 'BUY',
#   'price': '2378.25',
#   'qty': '0.118',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '280.63350',
#   'commission': '0.05612670',
#   'commissionAsset': 'USDT',
#   'time': 1702241908559,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3423454138,
#   'orderId': 8389765634017822155,
#   'side': 'SELL',
#   'price': '2234.58',
#   'qty': '0.118',
#   'realizedPnl': '-16.95306000',
#   'marginAsset': 'USDT',
#   'quoteQty': '263.68044',
#   'commission': '0',
#   'commissionAsset': 'USDT',
#   'time': 1702260766917,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3424320109,
#   'orderId': 8389765634060652257,
#   'side': 'SELL',
#   'price': '2233.62',
#   'qty': '0.018',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '40.20516',
#   'commission': '0.02010257',
#   'commissionAsset': 'USDT',
#   'time': 1702270016750,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3424320110,
#   'orderId': 8389765634060652257,
#   'side': 'SELL',
#   'price': '2233.62',
#   'qty': '0.062',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '138.48444',
#   'commission': '0.06924221',
#   'commissionAsset': 'USDT',
#   'time': 1702270016750,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3424372196,
#   'orderId': 8389765634066884713,
#   'side': 'BUY',
#   'price': '2244.80',
#   'qty': '0.080',
#   'realizedPnl': '-0.89440000',
#   'marginAsset': 'USDT',
#   'quoteQty': '179.58400',
#   'commission': '0.08979200',
#   'commissionAsset': 'USDT',
#   'time': 1702271912186,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3424759959,
#   'orderId': 8389765634108365697,
#   'side': 'BUY',
#   'price': '2238.11',
#   'qty': '0.080',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '179.04880',
#   'commission': '0.08952440',
#   'commissionAsset': 'USDT',
#   'time': 1702283474301,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3424775919,
#   'orderId': 8389765634110707248,
#   'side': 'SELL',
#   'price': '2241.46',
#   'qty': '0.080',
#   'realizedPnl': '0.26800000',
#   'marginAsset': 'USDT',
#   'quoteQty': '179.31680',
#   'commission': '0.08965840',
#   'commissionAsset': 'USDT',
#   'time': 1702284281685,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3424822347,
#   'orderId': 8389765634116097316,
#   'side': 'SELL',
#   'price': '2247.94',
#   'qty': '0.084',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '188.82696',
#   'commission': '0.09441348',
#   'commissionAsset': 'USDT',
#   'time': 1702286201709,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3424822831,
#   'orderId': 8389765634116149289,
#   'side': 'BUY',
#   'price': '2247.73',
#   'qty': '0.084',
#   'realizedPnl': '0.01764000',
#   'marginAsset': 'USDT',
#   'quoteQty': '188.80932',
#   'commission': '0.09440466',
#   'commissionAsset': 'USDT',
#   'time': 1702286217264,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3424841113,
#   'orderId': 8389765634118265501,
#   'side': 'SELL',
#   'price': '2244.36',
#   'qty': '0.080',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '179.54880',
#   'commission': '0.08977440',
#   'commissionAsset': 'USDT',
#   'time': 1702287088650,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3424854479,
#   'orderId': 8389765634119760987,
#   'side': 'BUY',
#   'price': '2250.01',
#   'qty': '0.080',
#   'realizedPnl': '-0.45200000',
#   'marginAsset': 'USDT',
#   'quoteQty': '180.00080',
#   'commission': '0.09000040',
#   'commissionAsset': 'USDT',
#   'time': 1702287690325,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3424873764,
#   'orderId': 8389765634122448355,
#   'side': 'BUY',
#   'price': '2247.62',
#   'qty': '0.080',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '179.80960',
#   'commission': '0.03596192',
#   'commissionAsset': 'USDT',
#   'time': 1702288687193,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3424878269,
#   'orderId': 8389765634122978900,
#   'side': 'SELL',
#   'price': '2249.87',
#   'qty': '0.080',
#   'realizedPnl': '0.18000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '179.98960',
#   'commission': '0.08999480',
#   'commissionAsset': 'USDT',
#   'time': 1702288866296,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3424882534,
#   'orderId': 8389765634123150956,
#   'side': 'BUY',
#   'price': '2251.32',
#   'qty': '0.084',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '189.11088',
#   'commission': '0.03782217',
#   'commissionAsset': 'USDT',
#   'time': 1702288933013,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3425537721,
#   'orderId': 8389765634190696824,
#   'side': 'SELL',
#   'price': '2216.06',
#   'qty': '0.084',
#   'realizedPnl': '-2.96184000',
#   'marginAsset': 'USDT',
#   'quoteQty': '186.14904',
#   'commission': '0.09307452',
#   'commissionAsset': 'USDT',
#   'time': 1702309971221,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3427260221,
#   'orderId': 8389765634350375897,
#   'side': 'BUY',
#   'price': '2226.80',
#   'qty': '0.019',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '42.30920',
#   'commission': '0.00846184',
#   'commissionAsset': 'USDT',
#   'time': 1702356753959,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3427274036,
#   'orderId': 8389765634352325859,
#   'side': 'SELL',
#   'price': '2219.63',
#   'qty': '0.019',
#   'realizedPnl': '-0.13623000',
#   'marginAsset': 'USDT',
#   'quoteQty': '42.17297',
#   'commission': '0.02108648',
#   'commissionAsset': 'USDT',
#   'time': 1702357137560,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3427284417,
#   'orderId': 8389765634353273816,
#   'side': 'BUY',
#   'price': '2221.82',
#   'qty': '0.080',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '177.74560',
#   'commission': '0.03554911',
#   'commissionAsset': 'USDT',
#   'time': 1702357438322,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3427288625,
#   'orderId': 8389765634353972625,
#   'side': 'SELL',
#   'price': '2224.61',
#   'qty': '0.080',
#   'realizedPnl': '0.22320000',
#   'marginAsset': 'USDT',
#   'quoteQty': '177.96880',
#   'commission': '0.08898440',
#   'commissionAsset': 'USDT',
#   'time': 1702357648918,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3427324618,
#   'orderId': 8389765634359107155,
#   'side': 'BUY',
#   'price': '2228.44',
#   'qty': '0.088',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '196.10272',
#   'commission': '0.09805136',
#   'commissionAsset': 'USDT',
#   'time': 1702359559583,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3427450109,
#   'orderId': 8389765634374083844,
#   'side': 'SELL',
#   'price': '2231.59',
#   'qty': '0.088',
#   'realizedPnl': '0.27720000',
#   'marginAsset': 'USDT',
#   'quoteQty': '196.37992',
#   'commission': '0.09818996',
#   'commissionAsset': 'USDT',
#   'time': 1702364606670,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3427495543,
#   'orderId': 8389765634379856912,
#   'side': 'BUY',
#   'price': '2227.90',
#   'qty': '0.097',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '216.10630',
#   'commission': '0.04322126',
#   'commissionAsset': 'USDT',
#   'time': 1702366663096,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'ETHUSDT',
#   'id': 3427500677,
#   'orderId': 8389765634380603245,
#   'side': 'SELL',
#   'price': '2230.99',
#   'qty': '0.097',
#   'realizedPnl': '0.29973000',
#   'marginAsset': 'USDT',
#   'quoteQty': '216.40603',
#   'commission': '0.10820301',
#   'commissionAsset': 'USDT',
#   'time': 1702366909609,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3427510087,
#   'orderId': 8389765634381611508,
#   'side': 'BUY',
#   'price': '2233.22',
#   'qty': '0.090',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '200.98980',
#   'commission': '0.10049490',
#   'commissionAsset': 'USDT',
#   'time': 1702367276412,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3427517067,
#   'orderId': 8389765634381982511,
#   'side': 'SELL',
#   'price': '2236.74',
#   'qty': '0.090',
#   'realizedPnl': '0.31680000',
#   'marginAsset': 'USDT',
#   'quoteQty': '201.30660',
#   'commission': '0.10065330',
#   'commissionAsset': 'USDT',
#   'time': 1702367407798,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3427522246,
#   'orderId': 8389765634382216527,
#   'side': 'BUY',
#   'price': '2237.48',
#   'qty': '0.011',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '24.61228',
#   'commission': '0.01230614',
#   'commissionAsset': 'USDT',
#   'time': 1702367506615,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'ETHUSDT',
#   'id': 3427522247,
#   'orderId': 8389765634382216527,
#   'side': 'BUY',
#   'price': '2237.48',
#   'qty': '0.088',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '196.89824',
#   'commission': '0.09844912',
#   'commissionAsset': 'USDT',
#   'time': 1702367506615,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False}]

# %%
symbol='ETHUSDT'
open_orders = client.futures_get_open_orders(symbol=symbol)

# %%
open_orders
# Out:
# [{'orderId': 8389765634384454324,
#   'symbol': 'ETHUSDT',
#   'status': 'NEW',
#   'clientOrderId': 'electron_p6horzpNH9jp5wgYZkiI',
#   'price': '0',
#   'avgPrice': '0',
#   'origQty': '0',
#   'executedQty': '0',
#   'cumQuote': '0.00000',
#   'timeInForce': 'GTE_GTC',
#   'type': 'STOP_MARKET',
#   'reduceOnly': True,
#   'closePosition': True,
#   'side': 'SELL',
#   'positionSide': 'BOTH',
#   'stopPrice': '2000',
#   'workingType': 'MARK_PRICE',
#   'priceProtect': True,
#   'origType': 'STOP_MARKET',
#   'priceMatch': 'NONE',
#   'selfTradePreventionMode': 'NONE',
#   'goodTillDate': 0,
#   'time': 1702368488973,
#   'updateTime': 1702368488973}]

# %%
position_info = client.futures_position_information(symbol=symbol)

# %%
position_info
# Out:
# [{'symbol': 'ETHUSDT',
#   'positionAmt': '0.099',
#   'entryPrice': '2237.48',
#   'breakEvenPrice': '2238.59874',
#   'markPrice': '2230.33000000',
#   'unRealizedProfit': '-0.70785000',
#   'liquidationPrice': '2194.73074981',
#   'leverage': '100',
#   'maxNotionalValue': '200000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '220.80267000',
#   'isolatedWallet': '0',
#   'updateTime': 1702367506615,
#   'isolated': False,
#   'adlQuantile': 2}]
