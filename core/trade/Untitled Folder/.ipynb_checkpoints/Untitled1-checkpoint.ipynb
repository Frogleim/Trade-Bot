# %%
from binance.client import Client
import matplotlib.pyplot as plt
import mplfinance as mpf
import pandas as pd

# %%
api_key = 'iyJXPaZztWrimkH6V57RGvStFgYQWRaaMdaYBQHHIEv0mMY1huCmrzTbXkaBjLFh'

api_secret = 'hmrus7zI9PW2EXqsDVovoS2cEFRVsxeETGgBf4XJInOLFcmIXKNL23alGRNRbXKI'
client = Client(api_key, api_secret)

# %%
interval='1m'
symbol = 'ETHUSDT'
n = 10

# %%
klines = client.futures_klines(symbol=symbol, interval=interval, limit=n)
len(klines)
# Out:
# 10

# %%
timestamps = [int(kline[0]) for kline in klines]
index=pd.to_datetime(timestamps, unit='ms')
index
# Out:
# DatetimeIndex(['2023-12-11 07:43:00', '2023-12-11 07:44:00',
#                '2023-12-11 07:45:00', '2023-12-11 07:46:00',
#                '2023-12-11 07:47:00', '2023-12-11 07:48:00',
#                '2023-12-11 07:49:00', '2023-12-11 07:50:00',
#                '2023-12-11 07:51:00', '2023-12-11 07:52:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
def plot_last_n_candles(symbol, interval='1m', n=10):
    klines = client.futures_klines(symbol=symbol, interval=interval, limit=n)

    # Extract relevant data
    timestamps = [int(kline[0]) for kline in klines]
    open_prices = [float(kline[1]) for kline in klines]
    high_prices = [float(kline[2]) for kline in klines]
    low_prices = [float(kline[3]) for kline in klines]
    close_prices = [float(kline[4]) for kline in klines]
    date=pd.to_datetime(timestamps, unit='ms')

    # Create a DataFrame with DatetimeIndex
    df = pd.DataFrame({
        'date': date,
        'open': open_prices,
        'high': high_prices,
        'low': low_prices,
        'close': close_prices,
    })
    print(df.head)

    # Plotting the last n candles

# %%
symbol = 'ETHUSDT'
interval = '1m'
direction = get_last_two_candles_direction(symbol, interval)
print(f'Direction: {direction}')
# Out:
# Direction: Down

# %%
#     plot_data = df.iloc[-n:]
#     print(plot_data)

#     mpf.plot(df, type='candle', style='yahoo', title=f'{symbol} Last {n} Candles', ylabel='Price', show_nontrading=True, num_displayed=n)
